# %%
import numpy as np
import matplotlib.pyplot as plt
from overshadowing_ber_2 import *

# %%
#Test noise power
measure_power(gaussian_noise(1000000, 15))
# Out:
# 14.98581804471084

# %%
plot_constellation(generate_qam_constellation(16))
plt.show()
plot_constellation(generate_psk_constellation(8))
plt.show()
print(measure_constellation_Eb(generate_qam_constellation(16)[0]))
print(measure_constellation_Eb(generate_psk_constellation(8)[0]))
# Out:
# 1.0
# 1.0000000000000002

# %%
plot_constellation(qam_constellations[16])
plot_decode(16, random_iq(10000, 5), decode_qam_constellation)
plt.show()

plot_constellation(psk_constellations[8])
plot_decode(8, random_iq(10000, 5), decode_psk_constellation)
plt.show()

# %%
qam_constellations[4]
# Out:
# (array([-1.-1.j,  1.-1.j, -1.+1.j,  1.+1.j]),
#  array([0, 2, 1, 3], dtype=int32),
#  (-1.0, 2.0))

# %%
psk_constellations[2][0][[0,1,1,0]]
# Out:
# array([ 1.+0.0000000e+00j, -1.+1.2246468e-16j, -1.+1.2246468e-16j,
#         1.+0.0000000e+00j])

# %%
attack_qam(256, 10000000, None, 23.5
, False)
# Out:
# 1.1375e-06
